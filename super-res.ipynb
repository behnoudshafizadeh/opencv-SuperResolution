# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/MyDrive/opencv-super-resolution")
# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# cv2.cpython-36m-x86_64-linux-gnu.so  super-res-adriyan.ipynb  test.png
# models				     super_res_image.py
# resize.png			     supres.png

# %%
# !python super_res_image.py --model models/ESPCN_x4.pb --image test.png
# Out:
# [INFO] loading super resolution model: models/ESPCN_x4.pb
# [INFO] model name: espcn
# [INFO] model scale: 4
# [INFO] w: 59, h: 13
# [INFO] super resolution took 0.008228 seconds
# [INFO] w: 236, h: 52
# [INFO] bicubic interpolation took 0.001224 seconds
